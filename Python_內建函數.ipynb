# %% [markdown]
# <a href="https://colab.research.google.com/github/MyDearGreatTeacher/HappyPythonDay/blob/master/Python_%E5%85%A7%E5%BB%BA%E5%87%BD%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Built in Functions(內建的函數)
#
#
# https://www.w3schools.com/python/python_ref_functions.asp

# %% [markdown]
# # ASCII 好幫手

# %%
chr(97)
# Out:
# 'a'

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# ### CTF解答:編碼與解碼 101     ASCII

# %%
a="66 114".split(" ")

result=''

for x in a:
#  print(chr(int(x)))
  y=chr(int(x))
#  y
  result += y
  
result
# Out:
# 'Br'

# %% [markdown]
# ### 自己的CTF自己出:
#
# 答案是BreakAllCTF{HappyPythonDay!A-LO_HA}
#
# 請提供數字要學員解答
